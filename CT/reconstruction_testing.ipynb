# %%
import sys, os
import numpy as np
import matplotlib.pyplot as plt

import data_making as dm
# %reload_ext autoreload
# %autoreload 2

# %%
root = r"F:\RawReconstructions"
exp_name = "osmoseflom_torrskan kjerne D 05b"
o_root = r"F:\ReconstructionDatasets"
o_name = "osmose_test"

# %%
osmose_test = dm.EquinorReconstructions(root, exp_name, o_root, o_name)

# %%
osmose_test.process_data([osmose_test])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 osmose_test.process_data([osmose_test])
#
# File f:\Repos\4D_CT\CT\data_making.py:88, in ReconstructionsDataCT.process_data(self, objects)
#      86     data = obj.reconstruct_target(o, f, index)
#      87     obj.reconstruct_noisy(o, f, data, index, self.n_angles)
# ---> 88     f.close()
#      90 o.close()
#      91 return
#
# AttributeError: 'NoneType' object has no attribute 'close'

# %%
import h5py
with h5py.File(os.path.join(o_root, f"{o_name}.h5"), "r") as f:
    data = np.array(f["noisy3D"]["00000"])

print(data.shape)
# Out:
# (1464, 783, 783)

# %%
plt.imshow(data.reshape((1464, 783, 783))[500], cmap="gray")
plt.show()

print(np.max(data))
# Geom issue.
# Out:
# 6164.1836
