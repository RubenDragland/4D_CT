# %%
import xml.etree.cElementTree as ET

# %%
tree = ET.parse("golden_angle_5min_mod_step0.nsiprg", parser= ET.XMLParser(encoding='iso-8859-5'))

root = tree.getroot()
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\Bruker\anaconda3\envs\CIL\lib\site-packages\IPython\core\interactiveshell.py:3460 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[23], line 1
#     tree = ET.parse("golden_angle_5min_mod_step0.nsiprg", parser= ET.XMLParser(encoding='iso-8859-5'))
#
#   File c:\Users\Bruker\anaconda3\envs\CIL\lib\xml\etree\ElementTree.py:1202 in parse
#     tree.parse(source, parser)
#
#   File c:\Users\Bruker\anaconda3\envs\CIL\lib\xml\etree\ElementTree.py:601 in parse
#     parser.feed(data)
#
#   File <string>
# ParseError: not well-formed (invalid token): line 1, column 12

# %%
def recursively_dict_value(keys, value):
    # print("len keys", len(keys))
    if len(keys) == 1:
        # dict[keys[0]] = value
        # return dict
        return {keys[0]: value}
    else:
        return {keys[0]: recursively_dict_value( keys[1:], value)}

# %%
test_dict = {}

test_dict["test"] = {}

upper_dict = {"test_dict": test_dict}
print(upper_dict)
# Out:
# {'test_dict': {'test': {}}}

# %%
with open("golden_angle_5min_mod_step0.nsiprg", "r") as f:
    data = f.readlines()
    data = [line.strip() for line in data]
    # print(data)

    list_of_dicts = []
    tot_dict = {}
    keys = []
    for line in data:
        k_start = line.find("<")
        k_end = line.find(">")
        key = line[k_start+1:k_end]
        keys.append(key)
        if f"{key[1:]}" in keys[:-1]:
            index = keys[:-1].index(key[1:])
            keys = keys[:index]
            continue
        info = line[k_end+1:]
        # print("line info", key, info)
        if len(info) == 0:
            continue
        else:
            list_of_dicts.append( recursively_dict_value(keys[1:], info) )
            tot_dict["/".join(keys)] = info
            # list_of_dicts.append(tot_dict)
            keys.pop()


# Be ready to tackle \ signs
print(tot_dict)
# Out:
# {'North Star Imaging DR-Program 1.0auto door': 'False', 'North Star Imaging DR-Program 1.0egress on end': 'False', 'North Star Imaging DR-Program 1.0stepname': 'step 0', 'North Star Imaging DR-Program 1.0stepmotionpositions': ' 0 0.00162763671875155 564.9625 564.962 930.000001289368 1349.98206295013 0.00151985006893263 0.000700000000001921 79.9999168945734 69.9999939453494', 'North Star Imaging DR-Program 1.0stepmotionspeeds': ' 20.8 18.4000015258789 11 10.75 28.8000011444092 9.60000038146973 1.95000143612132 5.6 5.10000498047144 5.40000527344035', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationProject folder': 'D:\\NTNU_metallic_undersampling', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationPart name': 'golden_angle_5min_mod', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationContinuous': 'False', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationRotation range': '0', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationMonitor Xray down': 'True', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationMonitor variation': '5', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationAuto Xoff': 'True', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationSave bitdepth': '32', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationNumbering start': '0', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationNumber of projections': '4', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFrame averaging': '12', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationDelay': '0', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationAdvanced': 'True', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationSuper advanced': 'False', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusDefectstatus': '7519 defective pixels (0,179266929626465%) (saved)', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetstatus': '0,0723, dev 0,00376, 400 fravg, 10 fps (acquired 08.02.2023 14:00:15)', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetfilename': 'D:\\NTNU_metallic_undersampling\\Corrections\\offset.tif', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationAcquisition Software': 'efX-dr v1.3.5.11', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSystem InfoCompany Name': 'North Star Imaging, Inc.', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSystem InfoModel Name': 'STATOILDR2', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSourcename': 'Gulmay MP1 [450kV]', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSourcefocal spot mode': '0', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSourcefocal spot mode description': 'Fine', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSourcefocal spot size microns': '400', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSourcekV': '250', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSourceuA': '2700', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSourceserial': '450kV', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field StatusOffsetFlat FieldTechnique ConfigurationSourceactual kV': '250', 'North Star Imaging DR-Program 1.0stepCT Project ConfigurationFlat Field Statu ...

# %%
tree = {}
keys = []
for i, item in enumerate(list_of_dicts):
    keys.append(list(item.keys())[0])

print(set(keys))

keys1 = []
for j, key1 in enumerate(keys):
    keys1.append(list(key1.keys())[0])
print(set(keys1))
# Fix tree formation
# Out:
# {'auto door', 'step', 'egress on end'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[158], line 10
#       8 keys1 = []
#       9 for j, key1 in enumerate(keys):
# ---> 10     keys1.append(list(key1.keys())[0])
#      11 print(set(keys1))
#
# AttributeError: 'str' object has no attribute 'keys'

# %%
# Try inner list instead:
# Do not see recursion version here...

def recursively_innerlist_dict_value(dict, keys, value):
    if len(keys) == 1:
        try:
            dict[keys[0]].append(value)
        except:
            dict[keys[0]] = [value]
        return dict
    else:
        return {keys[0]: recursively_innerlist_dict_value( dict[keys[0]], keys[1:], value)}

with open("golden_angle_5min_mod_step0.nsiprg", "r") as f:
    data = f.readlines()
    data = [line.strip() for line in data]
    # print(data)

    tot_dict = {}
    current_dict = tot_dict.copy()
    keys = []
    for line in data:
        k_start = line.find("<")
        k_end = line.find(">")
        key = line[k_start+1:k_end]
        keys.append(key)
        if f"{key[1:]}" in keys[:-1]:
            index = keys[:-1].index(key[1:])
            keys = keys[:index]
            continue
        info = line[k_end+1:]
        # print("line info", key, info)
        if len(info) == 0:
            current_dict = current_dict[key] = {}
        else:
            # list_of_dicts.append( recursively_dict_value(keys[1:], info) )
            # list_of_dicts.append(tot_dict)
            tot_dict = recursively_innerlist_dict_value(tot_dict, keys[:], info)
            keys.pop()

# %%
for d in list_of_dicts:
    print(d)
    print("\n")
# Out:
# {'auto door': 'False'}
#
#
# {'egress on end': 'False'}
#
#
# {'step': {'name': 'step 0'}}
#
#
# {'step': {'motion': {'positions': ' 0 0.00162763671875155 564.9625 564.962 930.000001289368 1349.98206295013 0.00151985006893263 0.000700000000001921 79.9999168945734 69.9999939453494'}}}
#
#
# {'step': {'motion': {'speeds': ' 20.8 18.4000015258789 11 10.75 28.8000011444092 9.60000038146973 1.95000143612132 5.6 5.10000498047144 5.40000527344035'}}}
#
#
# {'step': {'CT Project Configuration': {'Project folder': 'D:\\NTNU_metallic_undersampling'}}}
#
#
# {'step': {'CT Project Configuration': {'Part name': 'golden_angle_5min_mod'}}}
#
#
# {'step': {'CT Project Configuration': {'Continuous': 'False'}}}
#
#
# {'step': {'CT Project Configuration': {'Rotation range': '0'}}}
#
#
# {'step': {'CT Project Configuration': {'Monitor Xray down': 'True'}}}
#
#
# {'step': {'CT Project Configuration': {'Monitor variation': '5'}}}
#
#
# {'step': {'CT Project Configuration': {'Auto Xoff': 'True'}}}
#
#
# {'step': {'CT Project Configuration': {'Save bitdepth': '32'}}}
#
#
# {'step': {'CT Project Configuration': {'Numbering start': '0'}}}
#
#
# {'step': {'CT Project Configuration': {'Number of projections': '4'}}}
#
#
# {'step': {'CT Project Configuration': {'Frame averaging': '12'}}}
#
#
# {'step': {'CT Project Configuration': {'Delay': '0'}}}
#
#
# {'step': {'CT Project Configuration': {'Advanced': 'True'}}}
#
#
# {'step': {'CT Project Configuration': {'Super advanced': 'False'}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Defect': {'status': '7519 defective pixels (0,179266929626465%) (saved)'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'status': '0,0723, dev 0,00376, 400 fravg, 10 fps (acquired 08.02.2023 14:00:15)'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'filename': 'D:\\NTNU_metallic_undersampling\\Corrections\\offset.tif'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Acquisition Software': 'efX-dr v1.3.5.11'}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'System Info': {'Company Name': 'North Star Imaging, Inc.'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'System Info': {'Model Name': 'STATOILDR2'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Source': {'name': 'Gulmay MP1 [450kV]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode description': 'Fine'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot size microns': '400'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Source': {'kV': '250'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Source': {'uA': '2700'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Source': {'serial': '450kV'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Source': {'actual kV': '250'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Source': {'actual uA': '110'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'description': 'Perkin Elmer [XRD 1620/1621 AM/AN]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'type': 'Area'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'rotate code': '3'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'rotation description': '270 degree'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'horizontal flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'vertical flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'flip description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb': '10 10 10 10'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb description': '(l,t,r,b)=(10,10,10,10) pixels'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel width microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel height microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'width pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'height pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'bit depth': '16'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'gain': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'gain description': '0.25 pF'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'binning': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'binning description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'roi': '2048x2048+0+0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'integration time ms': '99.9288888888889'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Detector': {'fps': '10.0071161714997'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'motion': {'positions': ' -214748.3648 -335.378869342041 450 450 930.000001289368 1350.00000156403 -0.000445840992647106 0 80.0000037109797 69.9999939453494'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'motion': {'speeds': ' 20.8 18.4000015258789 11 10.75 28.8000011444092 9.60000038146973 1.95000143612132 5.6 5.10000498047144 5.40000527344035'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Setup': {'units': '[mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Setup': {'source to detector distance': '1350'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Setup': {'source to table distance': '930'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Setup': {'fixturing': {'phys filter': 'Cupper thin'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'ug text': '0,1806 [mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'center to object offset': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'zoom factor text': 'x1,45'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'IQI Hole (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '1'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'X Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '2'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Y Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Sqrt(Math.Pow($HPixelsIQI ,2) + Math.Pow($VPixelsIQI,2)) * $Srb /$IQI_Hole_Diameter'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Min Mag (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': 'NaN'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '4'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Pow(Math.Pow($Ug,3) + Math.Pow(2.0*$Srb,3 ),(double)1/3) / $v'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Im Unsharpness'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0,124'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'fravg': '400'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'acquisition begin': '08.02.2023 13:59:35'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Offset': {'Flat Field': {'acquisition end': '08.02.2023 14:00:15'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'id': '0'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'status': '0,71, dev 0,0598, 400 fravg, 10 fps (acquired 08.02.2023 12:59:16)'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'filename': 'D:\\NTNU_metallic_undersampling\\Corrections\\gain0.tif'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Acquisition Software': 'efX-dr v1.3.5.11'}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'System Info': {'Company Name': 'North Star Imaging, Inc.'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'System Info': {'Model Name': 'STATOILDR2'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'name': 'Gulmay MP1 [450kV]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode description': 'Fine'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot size microns': '400'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'kV': '250'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'uA': '2700'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'serial': '450kV'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'actual kV': '250'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'actual uA': '2710'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'description': 'Perkin Elmer [XRD 1620/1621 AM/AN]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'type': 'Area'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'rotate code': '3'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'rotation description': '270 degree'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'horizontal flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'vertical flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'flip description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb': '10 10 10 10'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb description': '(l,t,r,b)=(10,10,10,10) pixels'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel width microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel height microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'width pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'height pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'bit depth': '16'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'gain': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'gain description': '0.25 pF'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'binning': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'binning description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'roi': '2048x2048+0+0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'integration time ms': '99.9288888888889'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'fps': '10.0071161714997'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'motion': {'positions': ' -214748.3648 -335.378869342041 450 450 930.000001289368 1350.00000156403 -0.000445840992647106 0 80.0000037109797 69.9999939453494'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'motion': {'speeds': ' 20.8 18.4000015258789 11 10.75 28.8000011444092 9.60000038146973 1.95000143612132 5.6 5.10000498047144 5.40000527344035'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'units': '[mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'source to detector distance': '1350'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'source to table distance': '930'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'fixturing': {'phys filter': 'Cupper thin'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'ug text': '0,1806 [mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'center to object offset': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'zoom factor text': 'x1,45'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'IQI Hole (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '1'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'X Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '2'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Y Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Sqrt(Math.Pow($HPixelsIQI ,2) + Math.Pow($VPixelsIQI,2)) * $Srb /$IQI_Hole_Diameter'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Min Mag (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': 'NaN'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '4'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Pow(Math.Pow($Ug,3) + Math.Pow(2.0*$Srb,3 ),(double)1/3) / $v'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Im Unsharpness'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0,124'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'fravg': '400'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'acquisition begin': '08.02.2023 12:58:35'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'acquisition end': '08.02.2023 12:59:16'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'id': '1'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'status': '0,583, dev 0,0506, 400 fravg, 10 fps (acquired 08.02.2023 13:01:39)'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'filename': 'D:\\NTNU_metallic_undersampling\\Corrections\\gain1.tif'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Acquisition Software': 'efX-dr v1.3.5.11'}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'System Info': {'Company Name': 'North Star Imaging, Inc.'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'System Info': {'Model Name': 'STATOILDR2'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'name': 'Gulmay MP1 [450kV]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode description': 'Fine'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot size microns': '400'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'kV': '250'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'uA': '2200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'serial': '450kV'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'actual kV': '250'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'actual uA': '2210'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'description': 'Perkin Elmer [XRD 1620/1621 AM/AN]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'type': 'Area'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'rotate code': '3'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'rotation description': '270 degree'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'horizontal flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'vertical flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'flip description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb': '10 10 10 10'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb description': '(l,t,r,b)=(10,10,10,10) pixels'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel width microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel height microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'width pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'height pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'bit depth': '16'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'gain': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'gain description': '0.25 pF'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'binning': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'binning description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'roi': '2048x2048+0+0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'integration time ms': '99.9288888888889'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'fps': '10.0071161714997'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'motion': {'positions': ' -214748.3648 -335.378869342041 450 450 930.000001289368 1350.00000156403 -0.000445840992647106 0 80.0000037109797 69.9999939453494'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'motion': {'speeds': ' 20.8 18.4000015258789 11 10.75 28.8000011444092 9.60000038146973 1.95000143612132 5.6 5.10000498047144 5.40000527344035'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'units': '[mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'source to detector distance': '1350'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'source to table distance': '930'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'fixturing': {'phys filter': 'Cupper thin'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'ug text': '0,1806 [mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'center to object offset': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'zoom factor text': 'x1,45'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'IQI Hole (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '1'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'X Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '2'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Y Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Sqrt(Math.Pow($HPixelsIQI ,2) + Math.Pow($VPixelsIQI,2)) * $Srb /$IQI_Hole_Diameter'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Min Mag (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': 'NaN'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '4'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Pow(Math.Pow($Ug,3) + Math.Pow(2.0*$Srb,3 ),(double)1/3) / $v'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Im Unsharpness'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0,124'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'fravg': '400'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'acquisition begin': '08.02.2023 13:00:59'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'acquisition end': '08.02.2023 13:01:39'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'id': '2'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'status': '0,449, dev 0,0394, 400 fravg, 10 fps (acquired 08.02.2023 13:04:03)'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'filename': 'D:\\NTNU_metallic_undersampling\\Corrections\\gain2.tif'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Acquisition Software': 'efX-dr v1.3.5.11'}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'System Info': {'Company Name': 'North Star Imaging, Inc.'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'System Info': {'Model Name': 'STATOILDR2'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'name': 'Gulmay MP1 [450kV]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode description': 'Fine'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot size microns': '400'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'kV': '250'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'uA': '1700'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'serial': '450kV'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'actual kV': '250'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'actual uA': '1710'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'description': 'Perkin Elmer [XRD 1620/1621 AM/AN]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'type': 'Area'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'rotate code': '3'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'rotation description': '270 degree'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'horizontal flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'vertical flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'flip description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb': '10 10 10 10'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb description': '(l,t,r,b)=(10,10,10,10) pixels'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel width microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel height microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'width pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'height pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'bit depth': '16'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'gain': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'gain description': '0.25 pF'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'binning': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'binning description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'roi': '2048x2048+0+0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'integration time ms': '99.9288888888889'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'fps': '10.0071161714997'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'motion': {'positions': ' -214748.3648 -335.378869342041 450 450 930.000001289368 1350.00000156403 -0.000445840992647106 0 80.0000037109797 69.9999939453494'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'motion': {'speeds': ' 20.8 18.4000015258789 11 10.75 28.8000011444092 9.60000038146973 1.95000143612132 5.6 5.10000498047144 5.40000527344035'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'units': '[mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'source to detector distance': '1350'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'source to table distance': '930'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'fixturing': {'phys filter': 'Cupper thin'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'ug text': '0,1806 [mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'center to object offset': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'zoom factor text': 'x1,45'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'IQI Hole (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '1'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'X Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '2'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Y Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Sqrt(Math.Pow($HPixelsIQI ,2) + Math.Pow($VPixelsIQI,2)) * $Srb /$IQI_Hole_Diameter'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Min Mag (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': 'NaN'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '4'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Pow(Math.Pow($Ug,3) + Math.Pow(2.0*$Srb,3 ),(double)1/3) / $v'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Im Unsharpness'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0,124'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'fravg': '400'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'acquisition begin': '08.02.2023 13:03:23'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'acquisition end': '08.02.2023 13:04:03'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'id': '3'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'status': '0,314, dev 0,0277, 400 fravg, 10 fps (acquired 08.02.2023 13:06:26)'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'filename': 'D:\\NTNU_metallic_undersampling\\Corrections\\gain3.tif'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Acquisition Software': 'efX-dr v1.3.5.11'}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'System Info': {'Company Name': 'North Star Imaging, Inc.'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'System Info': {'Model Name': 'STATOILDR2'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'name': 'Gulmay MP1 [450kV]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Source': {'focal spot mode description': 'Fine'}}}}}}}}
#
#
# ...
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'horizontal flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'vertical flip': 'False'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'flip description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb': '10 10 10 10'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'crop ltrb description': '(l,t,r,b)=(10,10,10,10) pixels'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel width microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'pixel height microns': '200'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'width pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'height pixels': '2048'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'bit depth': '16'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'gain': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'gain description': '0.25 pF'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'binning': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'binning description': 'none'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'roi': '2048x2048+0+0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'integration time ms': '99.9288888888889'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Detector': {'fps': '10.0071161714997'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'motion': {'positions': ' -214748.3648 -335.378869342041 450 450 930.000001289368 1350.00000156403 -0.000445840992647106 0 80.0000037109797 69.9999939453494'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'motion': {'speeds': ' 20.8 18.4000015258789 11 10.75 28.8000011444092 9.60000038146973 1.95000143612132 5.6 5.10000498047144 5.40000527344035'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'units': '[mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'source to detector distance': '1350'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'source to table distance': '930'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Setup': {'fixturing': {'phys filter': 'Cupper thin'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'ug text': '0,1806 [mm]'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'center to object offset': '0'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'zoom factor text': 'x1,45'}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'IQI Hole (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '1'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'X Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '2'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Y Srb-Pixels (Hole)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '3'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Sqrt(Math.Pow($HPixelsIQI ,2) + Math.Pow($VPixelsIQI,2)) * $Srb /$IQI_Hole_Diameter'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Min Mag (mm)'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': 'NaN'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'idx': '4'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Pow(Math.Pow($Ug,3) + Math.Pow(2.0*$Srb,3 ),(double)1/3) / $v'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Im Unsharpness'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0,124'}}}}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'fravg': '400'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'acquisition begin': '08.02.2023 13:20:11'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Flat Field Status': {'Gain': {'Flat Field': {'acquisition end': '08.02.2023 13:20:51'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Acquisition Software': 'efX-dr v1.3.5.11'}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'System Info': {'Company Name': 'North Star Imaging, Inc.'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'System Info': {'Model Name': 'STATOILDR2'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Source': {'name': 'Gulmay MP1 [450kV]'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Source': {'focal spot mode': '0'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Source': {'focal spot mode description': 'Fine'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Source': {'focal spot size microns': '400'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Source': {'kV': '250'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Source': {'uA': '2700'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Source': {'serial': '450kV'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Source': {'actual kV': '250'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Source': {'actual uA': '2710'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'description': 'Perkin Elmer [XRD 1620/1621 AM/AN]'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'type': 'Area'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'rotate code': '3'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'rotation description': '270 degree'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'horizontal flip': 'False'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'vertical flip': 'False'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'flip description': 'none'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'crop ltrb': '10 10 10 10'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'crop ltrb description': '(l,t,r,b)=(10,10,10,10) pixels'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'pixel width microns': '200'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'pixel height microns': '200'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'width pixels': '2048'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'height pixels': '2048'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'bit depth': '16'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'gain': '0'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'gain description': '0.25 pF'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'binning': '0'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'binning description': 'none'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'roi': '2048x2048+0+0'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'integration time ms': '166.631111111111'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Detector': {'fps': '6.00128027312493'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'motion': {'positions': ' 0 0.00162763671875155 564.9625 564.962 930.000001289368 1349.98206295013 0.00151985006893263 0.000700000000001921 79.9999168945734 69.9999939453494'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'motion': {'speeds': ' 20.8 18.4000015258789 11 10.75 28.8000011444092 9.60000038146973 1.95000143612132 5.6 5.10000498047144 5.40000527344035'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Setup': {'units': '[mm]'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Setup': {'source to detector distance': '1349.982'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Setup': {'source to table distance': '930'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Setup': {'fixturing': {'phys filter': 'Cupper thin'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'ug text': '0,1806 [mm]'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'(0,903 pixels': '(0,903 pixels)'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'center to object offset': '0'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'zoom factor text': 'x1,45'}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'idx': '0'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '0'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'IQI Hole (mm)'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'idx': '1'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'X Srb-Pixels (Hole)'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'idx': '2'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Expression': '3'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Y Srb-Pixels (Hole)'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Value': '3'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'idx': '3'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Sqrt(Math.Pow($HPixelsIQI ,2) + Math.Pow($VPixelsIQI,2)) * $Srb /$IQI_Hole_Diameter'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Min Mag (mm)'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Value': 'NaN'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'idx': '4'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Expression': 'Math.Pow(Math.Pow($Ug,3) + Math.Pow(2.0*$Srb,3 ),(double)1/3) / $v'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Description': 'Im Unsharpness'}}}}}}
#
#
# {'step': {'CT Project Configuration': {'Technique Configuration': {'Ug': {'Formula': {'Value': '0,124'}}}}}}
#
#
# {'step': {'time stamp name': 'True'}}
#
#
# {'step': {'keep xon': 'true'}}
